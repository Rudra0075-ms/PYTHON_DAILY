# %%
#Student

class Student:
    def show(self):
        print("Student")

s = Student()
s.show()
# Out:
# Student

# %%
#Car

class Car:
    def start(self):
        print("Car Started")

Car().start()
# Out:
# Car Started

# %%
#Book

class Book:
    def read(self):
        print("Reading Book")

Book().read()
# Out:
# Reading Book

# %%
#laptop

class Laptop:
    def info(self):
        print("Asus Laptop")

Laptop().info()
# Out:
# Asus Laptop

# %%
#Mobile

class Mobile:
    def call(self):
        print("Calling...")

Mobile().call()
# Out:
# Calling...
